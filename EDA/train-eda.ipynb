# %% [markdown]
# #Classification of Water Consumption Types
#
# [Assignment SI - Infos](https://drive.google.com/file/d/1lh5a0YxVsC-NXtsIpucTVCrfJR_8KZB4/view?usp=sharing)
#
# [Dataset Train](https://virtual.ipb.pt/access/content/group/5b961040-5442-11ee-bfc7-421e367e2b5a/Assignment/train.csv)
#
# [Dataset Competition](https://virtual.ipb.pt/access/content/group/5b961040-5442-11ee-bfc7-421e367e2b5a/Assignment/competition.csv)

# %% [markdown]
# ### 1) **IMPORT** and **UTILITY**

# %% [markdown]
# Import all usefull libraries and define some usefull functions

# %%
###########################
# data libraries
###########################
import pandas as pd
import numpy as np

###########################
# plot libraries
###########################
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# ### 2) **READ DATA FILES**

# %% [markdown]
# Read data file uploaded to this google colab

# %%
###########################
# import csv in dataframe
###########################

train = pd.read_csv("train.csv")
# test = pd.read_csv("competition.csv")

# %% [markdown]
# ### 3) **Data Vizualization**

# %%
###########################
# see main data features
###########################
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227063 entries, 0 to 227062
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               227063 non-null  int64
#  1   Month              227063 non-null  int64
#  2   Consumer_type      227063 non-null  object
#  3   Consumption        227063 non-null  int64
#  4   Consumer_number    227063 non-null  object
#  5   Installation_zone  227063 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 10.4+ MB

# %%
train.head()
# Out:
#    Year  Month Consumer_type  Consumption     Consumer_number  \
# 0  2013      1      domestic            0  MOGV36480546611521
# 1  2013      1    industrial            5  BECS02817768252637
# 2  2013      1      domestic            6  VRFW65577141436242
# 3  2013      1      domestic            1  QLLI18662653137621
# 4  2013      1      domestic           13  HYUO61823402850645
#
#      Installation_zone
# 0  Installation_zone 1
# 1  Installation_zone 2
# 2  Installation_zone 2
# 3  Installation_zone 2
# 4  Installation_zone 2

# %%
# test.head()

# %%
train.describe(percentiles=None, include='all')
# Out:
#                  Year          Month Consumer_type    Consumption  \
# count   227063.000000  227063.000000        227063  227063.000000
# unique            NaN            NaN             7            NaN
# top               NaN            NaN      domestic            NaN
# freq              NaN            NaN        165343            NaN
# mean      2015.569534       6.324558           NaN       6.753108
# std          1.842505       3.422368           NaN      19.691717
# min       2013.000000       1.000000           NaN       0.000000
# 25%       2014.000000       3.000000           NaN       1.000000
# 50%       2016.000000       6.000000           NaN       5.000000
# 75%       2017.000000       9.000000           NaN       9.000000
# max       2018.000000      12.000000           NaN    4978.000000
#
#            Consumer_number    Installation_zone
# count               227063               227063
# unique               24505                   50
# ...

# %%
train.isnull().sum()
# Out:
# Year                 0
# Month                0
# Consumer_type        0
# Consumption          0
# Consumer_number      0
# Installation_zone    0
# dtype: int64

# %% [markdown]
# #### 3.1) Plot to find some correlation or outliers

# %%
# correlation between installation zone and consumption
plt.figure(figsize=(10, 10))
sns.scatterplot(data=train, x='Consumption',y='Installation_zone')
# Out:
# <Axes: xlabel='Consumption', ylabel='Installation_zone'>

# %%
# correlation between consumer type and consumption
plt.figure(figsize=(15, 6))
sns.scatterplot(data=train, x='Consumer_type',y='Consumption')
# Out:
# <Axes: xlabel='Consumer_type', ylabel='Consumption'>

# %% [markdown]
# ##### **We can see how more higher value of consumption generally correspond to an industrual consumer type, and generally correspond to an installation zone with a lower number**

# %%
# distribution of consumption over consumer type
plt.figure(figsize=(10, 6))
sns.boxplot(data=train, x="Consumption", y="Consumer_type")
# Out:
# <Axes: xlabel='Consumption', ylabel='Consumer_type'>

# %%
# counting how much users there are in an Consumer Type
# grouped by Installation Zone
plt.figure(figsize=(20, 20))
sns.histplot(data=train, x='Consumer_type',hue='Installation_zone',multiple="stack")
# Out:
# <Axes: xlabel='Consumer_type', ylabel='Count'>

# %%
sns.pairplot(data=train, hue='Consumer_type')

# %%
sns.pairplot(data=train, hue='Installation_zone')

# %%
sns.pairplot(data=train, hue='Month')
# sns.pairplot(data=test, hue='Month')

# %%
sns.heatmap(train.corr())
# Out:
# <ipython-input-15-1df3d0bfd6af>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train.corr())
# <Axes: >

# %%
train['Consumer_type'].hist()
# Out:
# <Axes: >

# %%
train['Installation_zone'].hist()
# Out:
# <Axes: >

# %%
train['Month'].hist()
# Out:
# <Axes: >

# %%
pd.set_option("display.max_rows", None)
train['Consumer_number'].value_counts()
# Out:
# GDKU38942785196943    32
# ZZML52718477240693    31
# KGXI38491240432727    30
# ZHVC51180765716340    30
# SVTO17262120844480    29
# GODY48335843845426    29
# CEHN86139617365229    29
# IWXJ31716285726673    28
# SLBY56054397945306    28
# DTSL66926834354228    28
# FOPM22892706367925    28
# MTJZ72031019004954    28
# LORC83889392450134    28
# MOAX19946590174327    28
# ZRYF38783893917576    28
# BJCM32993130006782    28
# JNTV22740938340248    27
# DOLF01356972974533    27
# EKPW40701820257435    27
# EEAS14524633508612    27
# PDFO51274363543835    27
# MBLA71290504725654    27
# YCON07527914360537    27
# BBOL56799254666458    27
# OFNL51398963556454    27
# HGVP04954618648795    27
# GQJF97611402663598    27
# JOKZ47022485911421    27
# JJCT29760871890199    27
# RCPN07364432947510    27
# REPS34909515613220    27
# TDRA59760281228898    27
# MREG35364822769248    27
# FYFW19432688106745    26
# FVWQ05089310643835    26
# TGMW61137402607632    26
# WVIJ71546029924489    26
# ...

# %%
sns.scatterplot(x=train['Month'], y=train['Consumption'])
# Out:
# <Axes: xlabel='Month', ylabel='Consumption'>

# %%
sns.barplot(x=train['Month'], y=train['Consumption'])
# Out:
# <Axes: xlabel='Month', ylabel='Consumption'>

# %%
train_domestic = train.loc[train['Consumer_type'] == 'domestic']
train_industrial = train.loc[train['Consumer_type'] == 'industrial']
train_rural_commercial = train.loc[train['Consumer_type'] == 'rural commercial']
train_construction = train.loc[train['Consumer_type'] == 'construction']
train_low_income_families = train.loc[train['Consumer_type'] == 'low income families']
train_rural_domestic = train.loc[train['Consumer_type'] == 'rural domestic']
train_rural_expansion = train.loc[train['Consumer_type'] == 'rural expansion']

# %%
sns.barplot(x=train_domestic['Month'], y=train_domestic['Consumption'])
# Out:
# <Axes: xlabel='Month', ylabel='Consumption'>

# %%
sns.barplot(x=train_industrial['Month'], y=train_industrial['Consumption'])
# Out:
# <Axes: xlabel='Month', ylabel='Consumption'>

# %%
sns.barplot(x=train_rural_commercial['Month'], y=train_rural_commercial['Consumption'])
# Out:
# <Axes: xlabel='Month', ylabel='Consumption'>

# %%
sns.barplot(x=train_construction['Month'], y=train_construction['Consumption'])
# Out:
# <Axes: xlabel='Month', ylabel='Consumption'>

# %%
sns.barplot(x=train_low_income_families['Month'], y=train_low_income_families['Consumption'])
# Out:
# <Axes: xlabel='Month', ylabel='Consumption'>

# %%
sns.barplot(x=train_rural_domestic['Month'], y=train_rural_domestic['Consumption'])
# Out:
# <Axes: xlabel='Month', ylabel='Consumption'>

# %%
sns.barplot(x=train_rural_expansion['Month'], y=train_rural_expansion['Consumption'])
# Out:
# <Axes: xlabel='Month', ylabel='Consumption'>

# %%
consumer_list = []
consumer_number_list = train['Consumer_number'].unique()

for consumer in consumer_number_list:
  consumer_examples = train.loc[train['Consumer_number'] == consumer]
  type_list = consumer_examples['Consumer_type'].unique()
  consumer_list.append( { consumer : type_list } )

# %%
for consumer in consumer_list:
  key = list(consumer.keys())[0]
  type_list = consumer.get(key)
  if len(type_list) > 1:
    print(consumer)
# Out:
# {'BRRN45011194906887': array(['domestic', 'low income families'], dtype=object)}
# {'ZTXB62277071332927': array(['domestic', 'low income families'], dtype=object)}
# {'BFNZ91758979264680': array(['domestic', 'low income families'], dtype=object)}
# {'EJRR94082279846978': array(['domestic', 'low income families'], dtype=object)}
# {'TXRC60025138635768': array(['domestic', 'low income families'], dtype=object)}
# {'TOIJ32662986851457': array(['low income families', 'domestic'], dtype=object)}
# {'EIBW79483707803266': array(['domestic', 'low income families'], dtype=object)}
# {'XPIZ50071980679028': array(['domestic', 'low income families'], dtype=object)}
# {'WKCP50077754358089': array(['low income families', 'domestic'], dtype=object)}
# {'LESR81245049449880': array(['domestic', 'low income families'], dtype=object)}
# {'TBHB68132836135028': array(['domestic', 'low income families'], dtype=object)}
# {'TWZX42106612273456': array(['domestic', 'low income families'], dtype=object)}
# ...
